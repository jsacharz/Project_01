# %%
import csv
import os
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd

# %%
clean_file = pd.read_csv("cleaned_data.csv", encoding = "ISO-8859-1")
clean_file.head()
# Out:
#    S. No.    Timestamp                  GADE    Game                 Platform  \
# 0       1  42052.00437  Not difficult at all  Skyrim  Console (PS, Xbox, ...)
# 1       2  42052.00680    Somewhat difficult   Other                       PC
# 2       3  42052.03860  Not difficult at all   Other                       PC
# 3       4  42052.06804  Not difficult at all   Other                       PC
# 4       5  42052.08948        Very difficult   Other  Console (PS, Xbox, ...)
#
#    Hours        earnings     whyplay League  streams  ...  \
# 0   15.0  I play for fun  having fun    NaN      0.0  ...
# 1    8.0  I play for fun  having fun    NaN      2.0  ...
# 2    0.0  I play for fun  having fun    NaN      0.0  ...
# 3   20.0  I play for fun   improving    NaN      5.0  ...
# 4   20.0  I play for fun  having fun    NaN      1.0  ...
#
#                                 Degree Birthplace    Residence  \
# 0             Bachelor (or equivalent)        USA          USA
# ...

# %%
js_file = pd.read_csv("GamingStudy_data_JS.csv", encoding = "ISO-8859-1")
js_file.head()
# Out:
#    S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0       1  42052.00437     0     0     0     0     1     0     0
# 1       2  42052.00680     1     2     2     2     0     1     0
# 2       3  42052.03860     0     2     2     0     0     3     1
# 3       4  42052.06804     0     0     0     0     0     0     0
# 4       5  42052.08948     2     1     2     2     2     3     2
#
#                    GADE  ...  Birthplace    Residence  Reference  \
# 0  Not difficult at all  ...         USA          USA     Reddit
# 1    Somewhat difficult  ...         USA          USA     Reddit
# 2  Not difficult at all  ...     Germany      Germany     Reddit
# 3  Not difficult at all  ...         USA          USA     Reddit
# 4        Very difficult  ...         USA  South Korea     Reddit
#
#                                            Playstyle  accept GAD_T SWL_T  \
# 0                                       Singleplayer  Accept     1    23
# ...

# %%
merged= pd.merge(clean_file, js_file, on =['Timestamp'], how ='left')
merged.head()
#merged["whyplay_y"].unique()



#cleaned_JS_df = merged[['S.No.'] = "S. No._x",
                   #   ['Timestamp'] = ]
# Out:
#    S. No._x    Timestamp                GADE_x  Game_x  \
# 0         1  42052.00437  Not difficult at all  Skyrim
# 1         2  42052.00680    Somewhat difficult   Other
# 2         3  42052.03860  Not difficult at all   Other
# 3         4  42052.06804  Not difficult at all   Other
# 4         5  42052.08948        Very difficult   Other
#
#                 Platform_x  Hours_x      earnings_x   whyplay_x League_x  \
# 0  Console (PS, Xbox, ...)     15.0  I play for fun  having fun      NaN
# 1                       PC      8.0  I play for fun  having fun      NaN
# 2                       PC      0.0  I play for fun  having fun      NaN
# 3                       PC     20.0  I play for fun   improving      NaN
# 4  Console (PS, Xbox, ...)     20.0  I play for fun  having fun      NaN
#
#    streams_x  ...  Birthplace_y  Residence_y  Reference  \
# 0        0.0  ...           USA          USA     Reddit
# 1        2.0  ...           USA          USA     Reddit
# ...

# %%
merged.columns
# Out:
# Index(['S. No._x', 'Timestamp', 'GADE_x', 'Game_x', 'Platform_x', 'Hours_x',
#        'earnings_x', 'whyplay_x', 'League_x', 'streams_x', 'Narcissism_x',
#        'Gender_x', 'Age_x', 'Work_x', 'Degree_x', 'Birthplace_x',
#        'Residence_x', 'Playstyle_x', 'accept_x', 'GAD_T_x', 'SWL_T_x',
#        'SPIN_T_x', 'Residence_ISO3_x', 'Birthplace_ISO3_x', 'S. No._y', 'GAD1',
#        'GAD2', 'GAD3', 'GAD4', 'GAD5', 'GAD6', 'GAD7', 'GADE_y', 'SWL1',
#        'SWL2', 'SWL3', 'SWL4', 'SWL5', 'Game_y', 'Platform_y', 'Hours_y',
#        'earnings_y', 'whyplay_y', 'League_y', 'highestleague', 'streams_y',
#        'SPIN1', 'SPIN2', 'SPIN3', 'SPIN4', 'SPIN5', 'SPIN6', 'SPIN7', 'SPIN8',
#        'SPIN9', 'SPIN10', 'SPIN11', 'SPIN12', 'SPIN13', 'SPIN14', 'SPIN15',
#        'SPIN16', 'SPIN17', 'Narcissism_y', 'Gender_y', 'Age_y', 'Work_y',
#        'Degree_y', 'Birthplace_y', 'Residence_y', 'Reference', 'Playstyle_y',
#        'accept_y', 'GAD_T_y', 'SWL_T_y', 'SPIN_T_y', 'Residence_ISO3_y',
# ...

# %%
merged.drop(['S. No._y', 'GAD1',
       'GAD2', 'GAD3', 'GAD4', 'GAD5', 'GAD6', 'GAD7', 'GADE_y', 'SWL1',
       'SWL2', 'SWL3', 'SWL4', 'SWL5', 'Game_y', 'Platform_y', 'Hours_y',
       'earnings_y', 'whyplay_x', 'League_y', 'highestleague', 'streams_y',
       'SPIN1', 'SPIN2', 'SPIN3', 'SPIN4', 'SPIN5', 'SPIN6', 'SPIN7', 'SPIN8',
       'SPIN9', 'SPIN10', 'SPIN11', 'SPIN12', 'SPIN13', 'SPIN14', 'SPIN15',
       'SPIN16', 'SPIN17', 'Narcissism_y', 'Gender_y', 'Age_y', 'Work_y',
       'Degree_y', 'Birthplace_y', 'Residence_y', 'Reference', 'Playstyle_y',
       'accept_y', 'GAD_T_y', 'SWL_T_y', 'SPIN_T_y', 'Residence_ISO3_y',
       'Birthplace_ISO3_y'], inplace=True, axis =1)

# %%
merged.head()
# Out:
#    S. No._x    Timestamp                GADE_x  Game_x  \
# 0         1  42052.00437  Not difficult at all  Skyrim
# 1         2  42052.00680    Somewhat difficult   Other
# 2         3  42052.03860  Not difficult at all   Other
# 3         4  42052.06804  Not difficult at all   Other
# 4         5  42052.08948        Very difficult   Other
#
#                 Platform_x  Hours_x      earnings_x League_x  streams_x  \
# 0  Console (PS, Xbox, ...)     15.0  I play for fun      NaN        0.0
# 1                       PC      8.0  I play for fun      NaN        2.0
# 2                       PC      0.0  I play for fun      NaN        0.0
# 3                       PC     20.0  I play for fun      NaN        5.0
# 4  Console (PS, Xbox, ...)     20.0  I play for fun      NaN        1.0
#
#    Narcissism_x  ... Birthplace_x  Residence_x  \
# 0           1.0  ...          USA          USA
# 1           1.0  ...          USA          USA
# 2           4.0  ...      Germany      Germany
# ...

# %%
merged.columns = ['S. No.', 'Timestamp', 'GADE', 'Game', 'Platform', 'Hours',
       'earnings', 'League', 'streams', 'Narcissism', 'Gender',
       'Age', 'Work', 'Degree', 'Birthplace', 'Residence',
       'Playstyle', 'accept', 'GAD_T', 'SWL_T', 'SPIN_T',
       'Residence_ISO3', 'Birthplace_ISO3', 'whyplay']

# %%
merged.head()
# Out:
#    S. No.    Timestamp                  GADE    Game                 Platform  \
# 0       1  42052.00437  Not difficult at all  Skyrim  Console (PS, Xbox, ...)
# 1       2  42052.00680    Somewhat difficult   Other                       PC
# 2       3  42052.03860  Not difficult at all   Other                       PC
# 3       4  42052.06804  Not difficult at all   Other                       PC
# 4       5  42052.08948        Very difficult   Other  Console (PS, Xbox, ...)
#
#    Hours        earnings League  streams  Narcissism  ... Birthplace  \
# 0   15.0  I play for fun    NaN      0.0         1.0  ...        USA
# 1    8.0  I play for fun    NaN      2.0         1.0  ...        USA
# 2    0.0  I play for fun    NaN      0.0         4.0  ...    Germany
# 3   20.0  I play for fun    NaN      5.0         2.0  ...        USA
# 4   20.0  I play for fun    NaN      1.0         1.0  ...        USA
#
#      Residence                                          Playstyle  accept  \
# ...

# %%
merged.to_csv('merged_js.csv')
