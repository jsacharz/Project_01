# %%
#Import Required Dependencies

import pandas as pd
import numpy as np
import os
import scipy.stats as stats
import re

# %%
# Importing updated csv file 

cleaned_df = pd.read_csv("cleaned_data_js_sc.csv", encoding="ISO-8859-1")

cleaned_df.head(10)
# Out:
#    S. No.    Timestamp                               GADE               Game  \
# 0       1  42052.00437  Both Singleplayer and Multiplayer             Skyrim
# 1       2  42052.00680                 Somewhat difficult              Other
# 2       3  42052.03860  Both Singleplayer and Multiplayer              Other
# 3       4  42052.06804  Both Singleplayer and Multiplayer              Other
# 4       5  42052.08948                     Very difficult              Other
# 5       6  42052.13119  Both Singleplayer and Multiplayer              Other
# 6       7  42052.14622  Both Singleplayer and Multiplayer              Other
# 7       9  42052.19737                     Very difficult              Other
# 8      10  42052.22995                 Somewhat difficult  World of Warcraft
# 9      11  42052.24204                 Somewhat difficult              Other
#
#                   Platform  Hours        earnings     whyplay League  streams  \
# ...

# %%
# To view all the rows in pandas
pd.set_option('display.max_rows', None)

# Value counts of League to determine the inputs
cleaned_df["League"].value_counts()
# Out:
# Gold                                                                                                                                                          843
# Silver                                                                                                                                                        583
# Platinum                                                                                                                                                      558
# Diamond                                                                                                                                                       471
# gold                                                                                                                                                          276
# Unranked                                                                                                                                                      232
# ...

# %%
## Converting the options on this to the following: 
# Unranked
# Ranked 
# Ranked - Challenger
# Ranked - Grandmsater
# Ranked - Master
# Ranked - Diamond
# Ranked - Platinum
# Ranked - Gold
# Ranked - Silver
# Ranked - Bronze

# for reference please visit - https://dotesports.com/league-of-legends/news/league-of-legends-ranking-system-explained-17171

# %%
# If cell value contains " ", "unranked", replace entire value with "Unranked"
cleaned_df["League"].fillna("Unranked", inplace=True)
cleaned_df["League"].replace(re.compile('.*unranked.*', re.IGNORECASE), 'Unranked', inplace=True,)
cleaned_df["League"].replace(re.compile('.*not ranked.*', re.IGNORECASE), 'Unranked', inplace=True,)
cleaned_df["League"].replace(re.compile('.*unraked.*', re.IGNORECASE), 'Unranked', inplace=True,)
cleaned_df["League"].replace(re.compile('.*not.*', re.IGNORECASE), 'Unranked', inplace=True,)
cleaned_df["League"].replace(re.compile('.*I don.*', re.IGNORECASE), 'Unranked', inplace=True,)
cleaned_df["League"].replace(re.compile('.*Haven.*', re.IGNORECASE), 'Unranked', inplace=True,)
cleaned_df["League"].replace(re.compile('.*Unrakned.*', re.IGNORECASE), 'Unranked', inplace=True,)
cleaned_df["League"].replace(re.compile('.*dont play.*', re.IGNORECASE), 'Unranked', inplace=True,)
cleaned_df["League"].replace(re.compile('.*nope.*', re.IGNORECASE), 'Unranked', inplace=True,)
cleaned_df["League"].replace(re.compile('.*no ranked.*', re.IGNORECASE), 'Unranked', inplace=True,)
cleaned_df["League"].replace(re.compile('.*new.*', re.IGNORECASE), 'Unranked', inplace=True,)
cleaned_df["League"].replace(re.compile('.*no longer.*', re.IGNORECASE), 'Unranked', inplace=True,)
cleaned_df["League"].replace(re.compile('.*unrank.*', re.IGNORECASE), 'Unranked', inplace=True,)


# If cell value contains "challenger", replace entire value with Ranked - Challenger
cleaned_df["League"].replace(re.compile('.*challenger.*', re.IGNORECASE), 'Ranked - Challenger', inplace=True,)


# If cell value contains "grand", replace entire value with Ranked - Grandmaster
cleaned_df["League"].replace(re.compile('.*grand.*', re.IGNORECASE), 'Ranked - Grandmaster', inplace=True,)


# If cell value contains "mast", replace entire value with Ranked - Master
cleaned_df["League"].replace(re.compile('.*mast.*', re.IGNORECASE), 'Ranked - Master', inplace=True,)


# If cell value contains "diamond", replace entire value with Ranked - Diamond
cleaned_df["League"].replace(re.compile('.*diamond.*', re.IGNORECASE), 'Ranked - Diamond', inplace=True,)
cleaned_df["League"].replace(re.compile('.*dia.*', re.IGNORECASE), 'Ranked - Diamond', inplace=True,)
cleaned_df["League"].replace(re.compile('.*legend.*', re.IGNORECASE), 'Ranked - Diamond', inplace=True,)
cleaned_df["League"].replace(re.compile('.*d1.*', re.IGNORECASE), 'Ranked - Diamond', inplace=True,)
cleaned_df["League"].replace(re.compile('.*d2.*', re.IGNORECASE), 'Ranked - Diamond', inplace=True,)
cleaned_df["League"].replace(re.compile('.*d3.*', re.IGNORECASE), 'Ranked - Diamond', inplace=True,)
cleaned_df["League"].replace(re.compile('.*d4.*', re.IGNORECASE), 'Ranked - Diamond', inplace=True,)
cleaned_df["League"].replace(re.compile('.*d5.*', re.IGNORECASE), 'Ranked - Diamond', inplace=True,)


# If cell value contains "platinum", replace entire value with Ranked - Platinum
cleaned_df["League"].replace(re.compile('.*platinum.*', re.IGNORECASE), 'Ranked - Platinum', inplace=True,)
cleaned_df["League"].replace(re.compile('.*plarinum.*', re.IGNORECASE), 'Ranked - Platinum', inplace=True,)
cleaned_df["League"].replace(re.compile('.*plat.*', re.IGNORECASE), 'Ranked - Platinum', inplace=True,)
cleaned_df["League"].replace(re.compile('.*p3.*', re.IGNORECASE), 'Ranked - Platinum', inplace=True,)
cleaned_df["League"].replace(re.compile('.*p1.*', re.IGNORECASE), 'Ranked - Platinum', inplace=True,)
cleaned_df["League"].replace(re.compile('.*p2.*', re.IGNORECASE), 'Ranked - Platinum', inplace=True,)
cleaned_df["League"].replace(re.compile('.*p4.*', re.IGNORECASE), 'Ranked - Platinum', inplace=True,)
cleaned_df["League"].replace(re.compile('.*p5.*', re.IGNORECASE), 'Ranked - Platinum', inplace=True,)


# If cell value contains "gold", replace entire value with Ranked - Gold
cleaned_df["League"].replace(re.compile('.*gold.*', re.IGNORECASE), 'Ranked - Gold', inplace=True,)
cleaned_df["League"].replace(re.compile('.*g1.*', re.IGNORECASE), 'Ranked - Gold', inplace=True,)
cleaned_df["League"].replace(re.compile('.*g2.*', re.IGNORECASE), 'Ranked - Gold', inplace=True,)
cleaned_df["League"].replace(re.compile('.*g3.*', re.IGNORECASE), 'Ranked - Gold', inplace=True,)
cleaned_df["League"].replace(re.compile('.*g4.*', re.IGNORECASE), 'Ranked - Gold', inplace=True,)
cleaned_df["League"].replace(re.compile('.*g5.*', re.IGNORECASE), 'Ranked - Gold', inplace=True,)
cleaned_df["League"].replace(re.compile('.*golf.*', re.IGNORECASE), 'Ranked - Gold', inplace=True,)
cleaned_df["League"].replace(re.compile('.*golld.*', re.IGNORECASE), 'Ranked - Gold', inplace=True,)


# If cell value contains "silver", replace entire value with Ranked - Silver
cleaned_df["League"].replace(re.compile('.*silver.*', re.IGNORECASE), 'Ranked - Silver', inplace=True,)
cleaned_df["League"].replace(re.compile('.*sliver.*', re.IGNORECASE), 'Ranked - Silver', inplace=True,)
cleaned_df["League"].replace(re.compile('.*s1.*', re.IGNORECASE), 'Ranked - Silver', inplace=True,)
cleaned_df["League"].replace(re.compile('.*s2.*', re.IGNORECASE), 'Ranked - Silver', inplace=True,)
cleaned_df["League"].replace(re.compile('.*s3.*', re.IGNORECASE), 'Ranked - Silver', inplace=True,)
cleaned_df["League"].replace(re.compile('.*s4.*', re.IGNORECASE), 'Ranked - Silver', inplace=True,)
cleaned_df["League"].replace(re.compile('.*s5.*', re.IGNORECASE), 'Ranked - Silver', inplace=True,)
cleaned_df["League"].replace(re.compile('.*siver.*', re.IGNORECASE), 'Ranked - Silver', inplace=True,)
cleaned_df["League"].replace(re.compile('.*silber.*', re.IGNORECASE), 'Ranked - Silver', inplace=True,)


# If cell value contains "bronze", replace entire value with Ranked - Bronze
cleaned_df["League"].replace(re.compile('.*bronze.*', re.IGNORECASE), 'Ranked - Bronze', inplace=True,)
cleaned_df["League"].replace(re.compile('.*b1.*', re.IGNORECASE), 'Ranked - Bronze', inplace=True,)
cleaned_df["League"].replace(re.compile('.*b2.*', re.IGNORECASE), 'Ranked - Bronze', inplace=True,)
cleaned_df["League"].replace(re.compile('.*b3.*', re.IGNORECASE), 'Ranked - Bronze', inplace=True,)
cleaned_df["League"].replace(re.compile('.*b4.*', re.IGNORECASE), 'Ranked - Bronze', inplace=True,)
cleaned_df["League"].replace(re.compile('.*b5.*', re.IGNORECASE), 'Ranked - Bronze', inplace=True,)
cleaned_df["League"].replace(re.compile('.*bronce.*', re.IGNORECASE), 'Ranked - Bronze', inplace=True,)
cleaned_df["League"].replace(re.compile('.*broze.*', re.IGNORECASE), 'Ranked - Bronze', inplace=True,)

# If cell value contains "singleplayer", "Multiplayer", etc.., replace entire value with Ranked
cleaned_df["League"].replace(re.compile('.*player.*', re.IGNORECASE), 'Ranked', inplace=True,)
cleaned_df["League"].replace(re.compile('.*tier.*', re.IGNORECASE), 'Ranked', inplace=True,)
cleaned_df["League"].replace(re.compile('.*mmr.*', re.IGNORECASE), 'Ranked', inplace=True,)
cleaned_df["League"].replace(re.compile('.*placements.*', re.IGNORECASE), 'Ranked', inplace=True,)
cleaned_df["League"].replace(re.compile('.*mmr.*', re.IGNORECASE), 'Ranked', inplace=True,)



 


# for row in cleaned_df["League"]:
#     if row != "Unranked":

        # "Ranked - Challenger",
        # "Ranked - Grandmsater",
        # "Ranked - Master",
        # "Ranked - Diamond",
        # "Ranked - Platinum",
        # "Ranked - Gold",
        # "Ranked - Silver",
        # "Ranked - Bronze"]:
        #row = "Ranked"
        



        #row.replace({x,Ranked"})



cleaned_df.head()
# Out:
#    S. No.    Timestamp                               GADE    Game  \
# 0       1  42052.00437  Both Singleplayer and Multiplayer  Skyrim
# 1       2  42052.00680                 Somewhat difficult   Other
# 2       3  42052.03860  Both Singleplayer and Multiplayer   Other
# 3       4  42052.06804  Both Singleplayer and Multiplayer   Other
# 4       5  42052.08948                     Very difficult   Other
#
#                   Platform  Hours        earnings     whyplay    League  \
# 0  Console (PS, Xbox, ...)     15  I play for fun  having fun  Unranked
# 1                       PC      8  I play for fun  having fun  Unranked
# 2                       PC      0  I play for fun  having fun  Unranked
# 3                       PC     20  I play for fun   improving  Unranked
# 4  Console (PS, Xbox, ...)     20  I play for fun  having fun  Unranked
#
#    streams  ...                               Degree Birthplace    Residence  \
# ...

# %%
cleaned_df["League"].value_counts()
# Out:
# Ranked - Gold                             2728
# Ranked - Platinum                         2285
# Unranked                                  2250
# Ranked - Silver                           1967
# Ranked - Diamond                          1480
# Ranked - Bronze                            464
# Ranked - Master                            180
# Ranked                                     170
# DMG                                          7
# /                                            4
# Placements                                   4
# MGE                                          4
# placements                                   4
# 0                                            3
# Rank 8                                       3
# LEM                                          3
# Rank 15                                      2
# Rank 13                                      2
# GM                                           2
# Nova 2                                       2
# ...
